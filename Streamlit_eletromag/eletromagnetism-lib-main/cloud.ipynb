# %%
import electromagnetism as em

# %%
coil = em.coil.Coil(em.geometry.line([0,0,0],[1,1,2], max_seg_len=10e-5), invertRAxis=1)

# %%
coil.coilPath.shape
# Out:
# (24496, 3)

# %%
#coil.biotSavart3d(coil.cloud(int(10e3)))

# %%
espira = em.models.coil.Solenoid(10,0,3,1,10e-3, invertRAxis=1)

# %%
espira.coilPath
# Out:
# array([[ 0.00000000e+00,  1.00000000e+00,  0.00000000e+00],
#        [ 1.00049052e-02,  9.99949950e-01,  1.00000000e-02],
#        [ 2.00088090e-02,  9.99799804e-01,  2.00000000e-02],
#        [ 3.00107098e-02,  9.99549577e-01,  3.00000000e-02],
#        [ 4.00096065e-02,  9.99199295e-01,  4.00000000e-02],
#        [ 5.00044983e-02,  9.98748993e-01,  5.00000000e-02],
#        [ 5.99943846e-02,  9.98198715e-01,  6.00000000e-02],
#        [ 6.99782654e-02,  9.97548516e-01,  7.00000000e-02],
#        [ 7.99551413e-02,  9.96798463e-01,  8.00000000e-02],
#        [ 8.99240137e-02,  9.95948629e-01,  9.00000000e-02],
#        [ 9.98838846e-02,  9.94999100e-01,  1.00000000e-01],
#        [ 1.09833757e-01,  9.93949971e-01,  1.10000000e-01],
#        [ 1.19772635e-01,  9.92801348e-01,  1.20000000e-01],
#        [ 1.29699524e-01,  9.91553344e-01,  1.30000000e-01],
#        [ 1.39613430e-01,  9.90206085e-01,  1.40000000e-01],
#        [ 1.49513360e-01,  9.88759705e-01,  1.50000000e-01],
# ...

# %%
espira.biotSavart3d(espira.cloud(int(10e4)))
# Out:
# array([[-9.90206085e-01, -9.90166182e-01, -9.90126280e-01, ...,
#          2.99992020e+00,  2.99996010e+00,  3.00000000e+00],
#        [-9.90206085e-01, -9.90166182e-01, -9.90126280e-01, ...,
#          2.99992020e+00,  2.99996010e+00,  3.00000000e+00],
#        [-9.90206085e-01, -9.90166182e-01, -9.90126280e-01, ...,
#          2.99992020e+00,  2.99996010e+00,  3.00000000e+00],
#        [ 3.54711733e-10,  3.54726054e-10,  3.54740376e-10, ...,
#         -2.35216090e-10, -2.35208845e-10, -2.35201600e-10],
#        [-1.85939044e-10, -1.85944891e-10, -1.85950739e-10, ...,
#          9.56780316e-11,  9.56757256e-11,  9.56734198e-11],
#        [-2.50233805e-10, -2.50245767e-10, -2.50257730e-10, ...,
#          8.79128086e-11,  8.79099483e-11,  8.79070881e-11]],
#       shape=(6, 100000))

# %%
racetrack = em.models.coil.Racetrack([0,0,0], 2, 1, 10e-3, 0.2, 3, invertRAxis=1)

# %%
racetrack.biotSavart3d(racetrack.cloud(int(10e2)))
# Out:
# array([[-5.68500000e+00, -5.67361862e+00, -5.66223724e+00, ...,
#          5.66223724e+00,  5.67361862e+00,  5.68500000e+00],
#        [-5.68500000e+00, -5.67361862e+00, -5.66223724e+00, ...,
#          5.66223724e+00,  5.67361862e+00,  5.68500000e+00],
#        [-5.68500000e+00, -5.67361862e+00, -5.66223724e+00, ...,
#          5.66223724e+00,  5.67361862e+00,  5.68500000e+00],
#        [-1.42589321e-08, -1.43419990e-08, -1.44256734e-08, ...,
#         -1.43482420e-08, -1.42649585e-08, -1.41822796e-08],
#        [-1.50887392e-08, -1.51799944e-08, -1.52719505e-08, ...,
#         -1.52978794e-08, -1.52057925e-08, -1.51144074e-08],
#        [-4.39005193e-09, -4.43567635e-09, -4.48185508e-09, ...,
#         -4.52642772e-09, -4.48004607e-09, -4.43422004e-09]],
#       shape=(6, 1000))
